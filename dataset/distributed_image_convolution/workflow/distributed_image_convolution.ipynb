# %%
# %audit off
# %flow mode normal
import time
start_time = time.time()

# %% [markdown]
# # Tile-wise Image Convolution at Scale with TaskVine
#
# This notebook shows how to filter a very large image by **splitting it into tiles
# and sending each tile to remote TaskVine workers**.
# We keep the manager lightweight (no heavy math) while every worker:
#
# 1. receives one grayscale tile **plus** the desired 2-D kernel,
# 2. performs the convolution by the classic **im2col × GEMM** trick, and
# 3. streams the result back.

# %% [markdown]
# ## Remote Function `apply_convolution`
#
# The helper below is **serialized and shipped** to each worker.  It pads the tile, converts it to an “im2col” matrix without copies, runs a
# single matrix multiply (**GEMM**), and reshapes back to the original grid.

# %%
def apply_convolution(tile_np, kernel_np):
    """
    Convolve a single grayscale *tile* with the given 2-D `kernel_np`
    using the classic “im2col × GEMM” trick.

    This function is sent to **remote TaskVine workers**.  The manager
    passes:
        tile_np   – NumPy array, shape (H, W)   one image tile
        kernel_np – NumPy array, shape (k, k)   e.g. 3×3 or 5×5 filter

    It returns an array of identical shape (H, W) with the filter applied.
    """
    import numpy as np

    k = kernel_np.shape[0]
    pad = k // 2

    # 1. Same-padding with reflection keeps edges crisp
    padded = np.pad(tile_np, pad, mode="reflect")

    # 2. Efficient im2col: each sliding window becomes one row
    H, W = tile_np.shape
    shape   = (H, W, k, k)
    strides = (
        padded.strides[0], padded.strides[1],  # move across image
        padded.strides[0], padded.strides[1],  # move inside kernel window
    )
    patches = np.lib.stride_tricks.as_strided(
        padded, shape=shape, strides=strides, writeable=False
    )
    col = patches.reshape(H * W, -1)  # (H·W, k²)

    # 3. Core compute: (H·W × k²)  @  (k² × 1)  →  (H·W × 1)
    # General Matrix Multiplications (GEMM)
    out_flat = col @ kernel_np.reshape(-1, 1)

    # 4. Back to image grid
    return out_flat.reshape(H, W)
# Out:
# Error while executing the command:
# /bin/sh: line 1: /home/ec2-user/ccgrid/NBRewind/dataset/distributed_image_convolution/workflow/vv: No such file or directory
# /home/ec2-user/ccgrid/NBRewind/NBRewind/nbrewind_flinc.py:524: DeprecationWarning: co_lnotab is deprecated, use co_lines instead.
#   original_code.co_lnotab,
# restoring

# %% [markdown]
# ## 3 · Manager: define kernels, submit tasks, stitch results
#
# We pick an input image, a tile size, and a kernel name.
# The manager
#
# * creates the tile tasks (`vine.PythonTask(apply_convolution, …)`),
# * waits for completion with progress bars, then
# * reassembles the full image and saves the high-resolution output.

# %%
import numpy as np

# ---- 3 × 3 kernels as NumPy arrays --------------------------------
KERNELS = {
    "sharpen": np.array([
        [ 0, -1,  0],
        [-1,  5, -1],
        [ 0, -1,  0],
    ], dtype=np.float32),

    "gaussian_blur": (1/16) * np.array([
        [1, 2, 1],
        [2, 4, 2],
        [1, 2, 1],
    ], dtype=np.float32),

    "edge_sobel": np.array([
        [-1, 0, 1],
        [-2, 0, 2],
        [-1, 0, 1],
    ], dtype=np.float32),
}
# Out:
# restoring
# Error while executing the command:
# /bin/sh: line 1: /home/ec2-user/ccgrid/NBRewind/dataset/distributed_image_convolution/workflow/vv: No such file or directory

# %%
IMG_PATH   = "npp.jpg"
TILE_SIZE     = 256
SELECT_KERNEL =  "sharpen"  # options - "sharpen" | "gaussian_blur" | "edge_sobel"
# Out:
# Error while executing the command:
# /bin/sh: line 1: /home/ec2-user/ccgrid/NBRewind/dataset/distributed_image_convolution/workflow/vv: No such file or directory
#
# restoring

# %%
import os

manager_name = api_key = os.environ.get("VINE_MANAGER_NAME", "dconv")
print(f"Manager name: {manager_name}")

ports_str = os.environ.get("VINE_MANAGER_PORTS", "9123, 9150")
ports = [int(p.strip()) for p in ports_str.split(",")]
print(f"Manager Ports: {ports}")
# Out:
# Manager name: dconv
# Manager Ports: [9123, 9150]
# Error while executing the command:
# /bin/sh: line 1: /home/ec2-user/ccgrid/NBRewind/dataset/distributed_image_convolution/workflow/vv: No such file or directory
#
# restoring

# %%
# %%time
# ---- imports --------------------------------------------------------
# import math, ndcctools.taskvine as vine
import math, taskvine_rewind.vine_rewind as vine
from pathlib import Path
from PIL import Image
from tqdm.notebook import tqdm


kernel = KERNELS[SELECT_KERNEL]

# ---- load image -----------------------------------------------------
orig_img_rgb = Image.open(IMG_PATH).convert("RGB")
img_gray = orig_img_rgb.convert("L")
img_gray_np     = np.asarray(img_gray, dtype=np.float32)
H, W         = img_gray_np.shape
tiles_x      = math.ceil(W / TILE_SIZE)
tiles_y      = math.ceil(H / TILE_SIZE)
total_tiles  = tiles_x * tiles_y
print(f"[load] {W}×{H}px → {total_tiles} tiles ({tiles_x}×{tiles_y})")

# ---- TaskVine manager ----------------------------------------------
m = vine.RewindManager(ports, name=manager_name)
print(f"[manager] Listening on port {m.port}")

task_map = {}
results  = [[None]*tiles_x for _ in range(tiles_y)]

# ---- submit tasks ---------------------------------------------------
print("[submit] queuing tasks …")
count = 0
for iy in tqdm(range(tiles_y), desc="Submit rows"):
    for ix in range(tiles_x):
        y0, x0 = iy*TILE_SIZE, ix*TILE_SIZE
        y1, x1 = min(y0+TILE_SIZE, H), min(x0+TILE_SIZE, W)
        tile_np = img_gray_np[y0:y1, x0:x1].copy()
        tid = m.submit(vine.PythonTask(apply_convolution, tile_np, kernel))
        count+=1
        task_map[tid] = (ix, iy)
print("[submit] done")
print(count)
# ---- collect results ------------------------------------------------
from tqdm.notebook import tqdm as tq
print("[collect] waiting …")

count = 0
with tq(total=total_tiles, desc="Tiles done") as pbar:
    while not m.empty():
        t = m.wait(5)
        if not t:
            continue
        ix, iy = task_map[t.id]
        if t.successful():
            results[iy][ix] = t.output
            pbar.update(1)
        else:
            raise RuntimeError(f"tile ({ix},{iy}) failed: {t.result}")
        count += 1
        if count % 50 == 0:
            print(count)

# ---- stitch full image ---------------------------------------------
filtered = np.zeros_like(img_gray_np)
for iy in range(tiles_y):
    for ix in range(tiles_x):
        y0, x0 = iy*TILE_SIZE, ix*TILE_SIZE
        filtered[y0:y0+results[iy][ix].shape[0],
                 x0:x0+results[iy][ix].shape[1]] = results[iy][ix]

filtered_img = Image.fromarray(np.clip(filtered, 0, 255).astype("uint8"))
OUT_PATH = Path(IMG_PATH).with_stem(Path(IMG_PATH).stem + f"_{SELECT_KERNEL}")
filtered_img.save(OUT_PATH.with_suffix(".jpg"))
print(f"[output] saved '{OUT_PATH}.jpg'")
# Out:
# [load] 8000×8000px → 1024 tiles (32×32)
# [manager] Listening on port 9125
# [submit] queuing tasks …
# Submit rows:   0%|          | 0/32 [00:00<?, ?it/s]
# [DEBUG submit()] vine_task_id=1, task.id=1
# [DEBUG submit()] vine_task_id=2, task.id=2
# [DEBUG submit()] vine_task_id=3, task.id=3
# [DEBUG submit()] vine_task_id=4, task.id=4
# [DEBUG submit()] vine_task_id=5, task.id=5
# [DEBUG submit()] vine_task_id=6, task.id=6
# [DEBUG submit()] vine_task_id=7, task.id=7
# [DEBUG submit()] vine_task_id=8, task.id=8
# [DEBUG submit()] vine_task_id=9, task.id=9
# [DEBUG submit()] vine_task_id=10, task.id=10
# [DEBUG submit()] vine_task_id=11, task.id=11
# [DEBUG submit()] vine_task_id=12, task.id=12
# [DEBUG submit()] vine_task_id=13, task.id=13
# [DEBUG submit()] vine_task_id=14, task.id=14
# [DEBUG submit()] vine_task_id=15, task.id=15
# [DEBUG submit()] vine_task_id=16, task.id=16
# [DEBUG submit()] vine_task_id=17, task.id=17
# [DEBUG submit()] vine_task_id=18, task.id=18
# [DEBUG submit()] vine_task_id=19, task.id=19
# [DEBUG submit()] vine_task_id=20, task.id=20
# [DEBUG submit()] vine_task_id=21, task.id=21
# [DEBUG submit()] vine_task_id=22, task.id=22
# [DEBUG submit()] vine_task_id=23, task.id=23
# [DEBUG submit()] vine_task_id=24, task.id=24
# [DEBUG submit()] vine_task_id=25, task.id=25
# [DEBUG submit()] vine_task_id=26, task.id=26
# [DEBUG submit()] vine_task_id=27, task.id=27
# [DEBUG submit()] vine_task_id=28, task.id=28
# [DEBUG submit()] vine_task_id=29, task.id=29
# [DEBUG submit()] vine_task_id=30, task.id=30
# [DEBUG submit()] vine_task_id=31, task.id=31
# [DEBUG submit()] vine_task_id=32, task.id=32
# [DEBUG submit()] vine_task_id=33, task.id=33
# [DEBUG submit()] vine_task_id=34, task.id=34
# [DEBUG submit()] vine_task_id=35, task.id=35
# [DEBUG submit()] vine_task_id=36, task.id=36
# [DEBUG submit()] vine_task_id=37, task.id=37
# [DEBUG submit()] vine_task_id=38, task.id=38
# [DEBUG submit()] vine_task_id=39, task.id=39
# [DEBUG submit()] vine_task_id=40, task.id=40
# [DEBUG submit()] vine_task_id=41, task.id=41
# [DEBUG submit()] vine_task_id=42, task.id=42
# [DEBUG submit()] vine_task_id=43, task.id=43
# [DEBUG submit()] vine_task_id=44, task.id=44
# [DEBUG submit()] vine_task_id=45, task.id=45
# [DEBUG submit()] vine_task_id=46, task.id=46
# [DEBUG submit()] vine_task_id=47, task.id=47
# [DEBUG submit()] vine_task_id=48, task.id=48
# [DEBUG submit()] vine_task_id=49, task.id=49
# [DEBUG submit()] vine_task_id=50, task.id=50
# [DEBUG submit()] vine_task_id=51, task.id=51
# [DEBUG submit()] vine_task_id=52, task.id=52
# [DEBUG submit()] vine_task_id=53, task.id=53
# [DEBUG submit()] vine_task_id=54, task.id=54
# [DEBUG submit()] vine_task_id=55, task.id=55
# [DEBUG submit()] vine_task_id=56, task.id=56
# [DEBUG submit()] vine_task_id=57, task.id=57
# [DEBUG submit()] vine_task_id=58, task.id=58
# [DEBUG submit()] vine_task_id=59, task.id=59
# [DEBUG submit()] vine_task_id=60, task.id=60
# [DEBUG submit()] vine_task_id=61, task.id=61
# [DEBUG submit()] vine_task_id=62, task.id=62
# [DEBUG submit()] vine_task_id=63, task.id=63
# [DEBUG submit()] vine_task_id=64, task.id=64
# [DEBUG submit()] vine_task_id=65, task.id=65
# [DEBUG submit()] vine_task_id=66, task.id=66
# [DEBUG submit()] vine_task_id=67, task.id=67
# [DEBUG submit()] vine_task_id=68, task.id=68
# [DEBUG submit()] vine_task_id=69, task.id=69
# [DEBUG submit()] vine_task_id=70, task.id=70
# [DEBUG submit()] vine_task_id=71, task.id=71
# [DEBUG submit()] vine_task_id=72, task.id=72
# [DEBUG submit()] vine_task_id=73, task.id=73
# [DEBUG submit()] vine_task_id=74, task.id=74
# [DEBUG submit()] vine_task_id=75, task.id=75
# [DEBUG submit()] vine_task_id=76, task.id=76
# [DEBUG submit()] vine_task_id=77, task.id=77
# [DEBUG submit()] vine_task_id=78, task.id=78
# [DEBUG submit()] vine_task_id=79, task.id=79
# [DEBUG submit()] vine_task_id=80, task.id=80
# [DEBUG submit()] vine_task_id=81, task.id=81
# [DEBUG submit()] vine_task_id=82, task.id=82
# [DEBUG submit()] vine_task_id=83, task.id=83
# [DEBUG submit()] vine_task_id=84, task.id=84
# [DEBUG submit()] vine_task_id=85, task.id=85
# [DEBUG submit()] vine_task_id=86, task.id=86
# [DEBUG submit()] vine_task_id=87, task.id=87
# [DEBUG submit()] vine_task_id=88, task.id=88
# [DEBUG submit()] vine_task_id=89, task.id=89
# [DEBUG submit()] vine_task_id=90, task.id=90
# [DEBUG submit()] vine_task_id=91, task.id=91
# [DEBUG submit()] vine_task_id=92, task.id=92
# [DEBUG submit()] vine_task_id=93, task.id=93
# [DEBUG submit()] vine_task_id=94, task.id=94
# [DEBUG submit()] vine_task_id=95, task.id=95
# [DEBUG submit()] vine_task_id=96, task.id=96
# [DEBUG submit()] vine_task_id=97, task.id=97
# [DEBUG submit()] vine_task_id=98, task.id=98
# [DEBUG submit()] vine_task_id=99, task.id=99
# [DEBUG submit()] vine_task_id=100, task.id=100
# [DEBUG submit()] vine_task_id=101, task.id=101
# [DEBUG submit()] vine_task_id=102, task.id=102
# [DEBUG submit()] vine_task_id=103, task.id=103
# [DEBUG submit()] vine_task_id=104, task.id=104
# [DEBUG submit()] vine_task_id=105, task.id=105
# [DEBUG submit()] vine_task_id=106, task.id=106
# [DEBUG submit()] vine_task_id=107, task.id=107
# [DEBUG submit()] vine_task_id=108, task.id=108
# [DEBUG submit()] vine_task_id=109, task.id=109
# [DEBUG submit()] vine_task_id=110, task.id=110
# [DEBUG submit()] vine_task_id=111, task.id=111
# [DEBUG submit()] vine_task_id=112, task.id=112
# [DEBUG submit()] vine_task_id=113, task.id=113
# [DEBUG submit()] vine_task_id=114, task.id=114
# [DEBUG submit()] vine_task_id=115, task.id=115
# [DEBUG submit()] vine_task_id=116, task.id=116
# [DEBUG submit()] vine_task_id=117, task.id=117
# [DEBUG submit()] vine_task_id=118, task.id=118
# [DEBUG submit()] vine_task_id=119, task.id=119
# [DEBUG submit()] vine_task_id=120, task.id=120
# [DEBUG submit()] vine_task_id=121, task.id=121
# [DEBUG submit()] vine_task_id=122, task.id=122
# [DEBUG submit()] vine_task_id=123, task.id=123
# [DEBUG submit()] vine_task_id=124, task.id=124
# [DEBUG submit()] vine_task_id=125, task.id=125
# [DEBUG submit()] vine_task_id=126, task.id=126
# [DEBUG submit()] vine_task_id=127, task.id=127
# [DEBUG submit()] vine_task_id=128, task.id=128
# [DEBUG submit()] vine_task_id=129, task.id=129
# [DEBUG submit()] vine_task_id=130, task.id=130
# [DEBUG submit()] vine_task_id=131, task.id=131
# [DEBUG submit()] vine_task_id=132, task.id=132
# [DEBUG submit()] vine_task_id=133, task.id=133
# [DEBUG submit()] vine_task_id=134, task.id=134
# [DEBUG submit()] vine_task_id=135, task.id=135
# [DEBUG submit()] vine_task_id=136, task.id=136
# [DEBUG submit()] vine_task_id=137, task.id=137
# [DEBUG submit()] vine_task_id=138, task.id=138
# [DEBUG submit()] vine_task_id=139, task.id=139
# [DEBUG submit()] vine_task_id=140, task.id=140
# [DEBUG submit()] vine_task_id=141, task.id=141
# [DEBUG submit()] vine_task_id=142, task.id=142
# [DEBUG submit()] vine_task_id=143, task.id=143
# [DEBUG submit()] vine_task_id=144, task.id=144
# [DEBUG submit()] vine_task_id=145, task.id=145
# [DEBUG submit()] vine_task_id=146, task.id=146
# [DEBUG submit()] vine_task_id=147, task.id=147
# [DEBUG submit()] vine_task_id=148, task.id=148
# [DEBUG submit()] vine_task_id=149, task.id=149
# [DEBUG submit()] vine_task_id=150, task.id=150
# [DEBUG submit()] vine_task_id=151, task.id=151
# [DEBUG submit()] vine_task_id=152, task.id=152
# [DEBUG submit()] vine_task_id=153, task.id=153
# [DEBUG submit()] vine_task_id=154, task.id=154
# [DEBUG submit()] vine_task_id=155, task.id=155
# [DEBUG submit()] vine_task_id=156, task.id=156
# [DEBUG submit()] vine_task_id=157, task.id=157
# [DEBUG submit()] vine_task_id=158, task.id=158
# [DEBUG submit()] vine_task_id=159, task.id=159
# [DEBUG submit()] vine_task_id=160, task.id=160
# [DEBUG submit()] vine_task_id=161, task.id=161
# [DEBUG submit()] vine_task_id=162, task.id=162
# [DEBUG submit()] vine_task_id=163, task.id=163
# [DEBUG submit()] vine_task_id=164, task.id=164
# [DEBUG submit()] vine_task_id=165, task.id=165
# [DEBUG submit()] vine_task_id=166, task.id=166
# [DEBUG submit()] vine_task_id=167, task.id=167
# [DEBUG submit()] vine_task_id=168, task.id=168
# [DEBUG submit()] vine_task_id=169, task.id=169
# [DEBUG submit()] vine_task_id=170, task.id=170
# [DEBUG submit()] vine_task_id=171, task.id=171
# [DEBUG submit()] vine_task_id=172, task.id=172
# [DEBUG submit()] vine_task_id=173, task.id=173
# [DEBUG submit()] vine_task_id=174, task.id=174
# [DEBUG submit()] vine_task_id=175, task.id=175
# [DEBUG submit()] vine_task_id=176, task.id=176
# [DEBUG submit()] vine_task_id=177, task.id=177
# [DEBUG submit()] vine_task_id=178, task.id=178
# [DEBUG submit()] vine_task_id=179, task.id=179
# [DEBUG submit()] vine_task_id=180, task.id=180
# [DEBUG submit()] vine_task_id=181, task.id=181
# [DEBUG submit()] vine_task_id=182, task.id=182
# [DEBUG submit()] vine_task_id=183, task.id=183
# [DEBUG submit()] vine_task_id=184, task.id=184
# [DEBUG submit()] vine_task_id=185, task.id=185
# [DEBUG submit()] vine_task_id=186, task.id=186
# [DEBUG submit()] vine_task_id=187, task.id=187
# [DEBUG submit()] vine_task_id=188, task.id=188
# [DEBUG submit()] vine_task_id=189, task.id=189
# [DEBUG submit()] vine_task_id=190, task.id=190
# [DEBUG submit()] vine_task_id=191, task.id=191
# [DEBUG submit()] vine_task_id=192, task.id=192
# [DEBUG submit()] vine_task_id=193, task.id=193
# [DEBUG submit()] vine_task_id=194, task.id=194
# [DEBUG submit()] vine_task_id=195, task.id=195
# [DEBUG submit()] vine_task_id=196, task.id=196
# [DEBUG submit()] vine_task_id=197, task.id=197
# [DEBUG submit()] vine_task_id=198, task.id=198
# [DEBUG submit()] vine_task_id=199, task.id=199
# [DEBUG submit()] vine_task_id=200, task.id=200
# [DEBUG submit()] vine_task_id=201, task.id=201
# [DEBUG submit()] vine_task_id=202, task.id=202
# [DEBUG submit()] vine_task_id=203, task.id=203
# [DEBUG submit()] vine_task_id=204, task.id=204
# [DEBUG submit()] vine_task_id=205, task.id=205
# [DEBUG submit()] vine_task_id=206, task.id=206
# [DEBUG submit()] vine_task_id=207, task.id=207
# [DEBUG submit()] vine_task_id=208, task.id=208
# [DEBUG submit()] vine_task_id=209, task.id=209
# [DEBUG submit()] vine_task_id=210, task.id=210
# [DEBUG submit()] vine_task_id=211, task.id=211
# [DEBUG submit()] vine_task_id=212, task.id=212
# [DEBUG submit()] vine_task_id=213, task.id=213
# [DEBUG submit()] vine_task_id=214, task.id=214
# [DEBUG submit()] vine_task_id=215, task.id=215
# [DEBUG submit()] vine_task_id=216, task.id=216
# [DEBUG submit()] vine_task_id=217, task.id=217
# [DEBUG submit()] vine_task_id=218, task.id=218
# [DEBUG submit()] vine_task_id=219, task.id=219
# [DEBUG submit()] vine_task_id=220, task.id=220
# [DEBUG submit()] vine_task_id=221, task.id=221
# [DEBUG submit()] vine_task_id=222, task.id=222
# [DEBUG submit()] vine_task_id=223, task.id=223
# [DEBUG submit()] vine_task_id=224, task.id=224
# [DEBUG submit()] vine_task_id=225, task.id=225
# [DEBUG submit()] vine_task_id=226, task.id=226
# [DEBUG submit()] vine_task_id=227, task.id=227
# [DEBUG submit()] vine_task_id=228, task.id=228
# [DEBUG submit()] vine_task_id=229, task.id=229
# [DEBUG submit()] vine_task_id=230, task.id=230
# [DEBUG submit()] vine_task_id=231, task.id=231
# [DEBUG submit()] vine_task_id=232, task.id=232
# [DEBUG submit()] vine_task_id=233, task.id=233
# [DEBUG submit()] vine_task_id=234, task.id=234
# [DEBUG submit()] vine_task_id=235, task.id=235
# [DEBUG submit()] vine_task_id=236, task.id=236
# [DEBUG submit()] vine_task_id=237, task.id=237
# [DEBUG submit()] vine_task_id=238, task.id=238
# [DEBUG submit()] vine_task_id=239, task.id=239
# [DEBUG submit()] vine_task_id=240, task.id=240
# [DEBUG submit()] vine_task_id=241, task.id=241
# [DEBUG submit()] vine_task_id=242, task.id=242
# [DEBUG submit()] vine_task_id=243, task.id=243
# [DEBUG submit()] vine_task_id=244, task.id=244
# [DEBUG submit()] vine_task_id=245, task.id=245
# [DEBUG submit()] vine_task_id=246, task.id=246
# [DEBUG submit()] vine_task_id=247, task.id=247
# [DEBUG submit()] vine_task_id=248, task.id=248
# [DEBUG submit()] vine_task_id=249, task.id=249
# [DEBUG submit()] vine_task_id=250, task.id=250
# [DEBUG submit()] vine_task_id=251, task.id=251
# [DEBUG submit()] vine_task_id=252, task.id=252
# [DEBUG submit()] vine_task_id=253, task.id=253
# [DEBUG submit()] vine_task_id=254, task.id=254
# [DEBUG submit()] vine_task_id=255, task.id=255
# [DEBUG submit()] vine_task_id=256, task.id=256
# [DEBUG submit()] vine_task_id=257, task.id=257
# [DEBUG submit()] vine_task_id=258, task.id=258
# [DEBUG submit()] vine_task_id=259, task.id=259
# [DEBUG submit()] vine_task_id=260, task.id=260
# [DEBUG submit()] vine_task_id=261, task.id=261
# [DEBUG submit()] vine_task_id=262, task.id=262
# [DEBUG submit()] vine_task_id=263, task.id=263
# [DEBUG submit()] vine_task_id=264, task.id=264
# [DEBUG submit()] vine_task_id=265, task.id=265
# [DEBUG submit()] vine_task_id=266, task.id=266
# [DEBUG submit()] vine_task_id=267, task.id=267
# [DEBUG submit()] vine_task_id=268, task.id=268
# [DEBUG submit()] vine_task_id=269, task.id=269
# [DEBUG submit()] vine_task_id=270, task.id=270
# [DEBUG submit()] vine_task_id=271, task.id=271
# [DEBUG submit()] vine_task_id=272, task.id=272
# [DEBUG submit()] vine_task_id=273, task.id=273
# [DEBUG submit()] vine_task_id=274, task.id=274
# [DEBUG submit()] vine_task_id=275, task.id=275
# [DEBUG submit()] vine_task_id=276, task.id=276
# [DEBUG submit()] vine_task_id=277, task.id=277
# [DEBUG submit()] vine_task_id=278, task.id=278
# [DEBUG submit()] vine_task_id=279, task.id=279
# [DEBUG submit()] vine_task_id=280, task.id=280
# [DEBUG submit()] vine_task_id=281, task.id=281
# [DEBUG submit()] vine_task_id=282, task.id=282
# [DEBUG submit()] vine_task_id=283, task.id=283
# [DEBUG submit()] vine_task_id=284, task.id=284
# [DEBUG submit()] vine_task_id=285, task.id=285
# [DEBUG submit()] vine_task_id=286, task.id=286
# [DEBUG submit()] vine_task_id=287, task.id=287
# [DEBUG submit()] vine_task_id=288, task.id=288
# [DEBUG submit()] vine_task_id=289, task.id=289
# [DEBUG submit()] vine_task_id=290, task.id=290
# [DEBUG submit()] vine_task_id=291, task.id=291
# [DEBUG submit()] vine_task_id=292, task.id=292
# [DEBUG submit()] vine_task_id=293, task.id=293
# [DEBUG submit()] vine_task_id=294, task.id=294
# [DEBUG submit()] vine_task_id=295, task.id=295
# [DEBUG submit()] vine_task_id=296, task.id=296
# [DEBUG submit()] vine_task_id=297, task.id=297
# [DEBUG submit()] vine_task_id=298, task.id=298
# [DEBUG submit()] vine_task_id=299, task.id=299
# [DEBUG submit()] vine_task_id=300, task.id=300
# [DEBUG submit()] vine_task_id=301, task.id=301
# [DEBUG submit()] vine_task_id=302, task.id=302
# [DEBUG submit()] vine_task_id=303, task.id=303
# [DEBUG submit()] vine_task_id=304, task.id=304
# [DEBUG submit()] vine_task_id=305, task.id=305
# [DEBUG submit()] vine_task_id=306, task.id=306
# [DEBUG submit()] vine_task_id=307, task.id=307
# [DEBUG submit()] vine_task_id=308, task.id=308
# [DEBUG submit()] vine_task_id=309, task.id=309
# [DEBUG submit()] vine_task_id=310, task.id=310
# [DEBUG submit()] vine_task_id=311, task.id=311
# [DEBUG submit()] vine_task_id=312, task.id=312
# [DEBUG submit()] vine_task_id=313, task.id=313
# [DEBUG submit()] vine_task_id=314, task.id=314
# [DEBUG submit()] vine_task_id=315, task.id=315
# [DEBUG submit()] vine_task_id=316, task.id=316
# [DEBUG submit()] vine_task_id=317, task.id=317
# [DEBUG submit()] vine_task_id=318, task.id=318
# [DEBUG submit()] vine_task_id=319, task.id=319
# [DEBUG submit()] vine_task_id=320, task.id=320
# [DEBUG submit()] vine_task_id=321, task.id=321
# [DEBUG submit()] vine_task_id=322, task.id=322
# [DEBUG submit()] vine_task_id=323, task.id=323
# [DEBUG submit()] vine_task_id=324, task.id=324
# [DEBUG submit()] vine_task_id=325, task.id=325
# [DEBUG submit()] vine_task_id=326, task.id=326
# [DEBUG submit()] vine_task_id=327, task.id=327
# [DEBUG submit()] vine_task_id=328, task.id=328
# [DEBUG submit()] vine_task_id=329, task.id=329
# [DEBUG submit()] vine_task_id=330, task.id=330
# [DEBUG submit()] vine_task_id=331, task.id=331
# [DEBUG submit()] vine_task_id=332, task.id=332
# [DEBUG submit()] vine_task_id=333, task.id=333
# [DEBUG submit()] vine_task_id=334, task.id=334
# [DEBUG submit()] vine_task_id=335, task.id=335
# [DEBUG submit()] vine_task_id=336, task.id=336
# [DEBUG submit()] vine_task_id=337, task.id=337
# [DEBUG submit()] vine_task_id=338, task.id=338
# [DEBUG submit()] vine_task_id=339, task.id=339
# [DEBUG submit()] vine_task_id=340, task.id=340
# [DEBUG submit()] vine_task_id=341, task.id=341
# [DEBUG submit()] vine_task_id=342, task.id=342
# [DEBUG submit()] vine_task_id=343, task.id=343
# [DEBUG submit()] vine_task_id=344, task.id=344
# [DEBUG submit()] vine_task_id=345, task.id=345
# [DEBUG submit()] vine_task_id=346, task.id=346
# [DEBUG submit()] vine_task_id=347, task.id=347
# [DEBUG submit()] vine_task_id=348, task.id=348
# [DEBUG submit()] vine_task_id=349, task.id=349
# [DEBUG submit()] vine_task_id=350, task.id=350
# [DEBUG submit()] vine_task_id=351, task.id=351
# [DEBUG submit()] vine_task_id=352, task.id=352
# [DEBUG submit()] vine_task_id=353, task.id=353
# [DEBUG submit()] vine_task_id=354, task.id=354
# [DEBUG submit()] vine_task_id=355, task.id=355
# [DEBUG submit()] vine_task_id=356, task.id=356
# [DEBUG submit()] vine_task_id=357, task.id=357
# [DEBUG submit()] vine_task_id=358, task.id=358
# [DEBUG submit()] vine_task_id=359, task.id=359
# [DEBUG submit()] vine_task_id=360, task.id=360
# [DEBUG submit()] vine_task_id=361, task.id=361
# [DEBUG submit()] vine_task_id=362, task.id=362
# [DEBUG submit()] vine_task_id=363, task.id=363
# [DEBUG submit()] vine_task_id=364, task.id=364
# [DEBUG submit()] vine_task_id=365, task.id=365
# [DEBUG submit()] vine_task_id=366, task.id=366
# [DEBUG submit()] vine_task_id=367, task.id=367
# [DEBUG submit()] vine_task_id=368, task.id=368
# [DEBUG submit()] vine_task_id=369, task.id=369
# [DEBUG submit()] vine_task_id=370, task.id=370
# [DEBUG submit()] vine_task_id=371, task.id=371
# [DEBUG submit()] vine_task_id=372, task.id=372
# [DEBUG submit()] vine_task_id=373, task.id=373
# [DEBUG submit()] vine_task_id=374, task.id=374
# [DEBUG submit()] vine_task_id=375, task.id=375
# [DEBUG submit()] vine_task_id=376, task.id=376
# [DEBUG submit()] vine_task_id=377, task.id=377
# [DEBUG submit()] vine_task_id=378, task.id=378
# [DEBUG submit()] vine_task_id=379, task.id=379
# [DEBUG submit()] vine_task_id=380, task.id=380
# [DEBUG submit()] vine_task_id=381, task.id=381
# [DEBUG submit()] vine_task_id=382, task.id=382
# [DEBUG submit()] vine_task_id=383, task.id=383
# [DEBUG submit()] vine_task_id=384, task.id=384
# [DEBUG submit()] vine_task_id=385, task.id=385
# [DEBUG submit()] vine_task_id=386, task.id=386
# [DEBUG submit()] vine_task_id=387, task.id=387
# [DEBUG submit()] vine_task_id=388, task.id=388
# [DEBUG submit()] vine_task_id=389, task.id=389
# [DEBUG submit()] vine_task_id=390, task.id=390
# [DEBUG submit()] vine_task_id=391, task.id=391
# [DEBUG submit()] vine_task_id=392, task.id=392
# [DEBUG submit()] vine_task_id=393, task.id=393
# [DEBUG submit()] vine_task_id=394, task.id=394
# [DEBUG submit()] vine_task_id=395, task.id=395
# [DEBUG submit()] vine_task_id=396, task.id=396
# [DEBUG submit()] vine_task_id=397, task.id=397
# [DEBUG submit()] vine_task_id=398, task.id=398
# [DEBUG submit()] vine_task_id=399, task.id=399
# [DEBUG submit()] vine_task_id=400, task.id=400
# [DEBUG submit()] vine_task_id=401, task.id=401
# [DEBUG submit()] vine_task_id=402, task.id=402
# [DEBUG submit()] vine_task_id=403, task.id=403
# [DEBUG submit()] vine_task_id=404, task.id=404
# [DEBUG submit()] vine_task_id=405, task.id=405
# [DEBUG submit()] vine_task_id=406, task.id=406
# [DEBUG submit()] vine_task_id=407, task.id=407
# [DEBUG submit()] vine_task_id=408, task.id=408
# [DEBUG submit()] vine_task_id=409, task.id=409
# [DEBUG submit()] vine_task_id=410, task.id=410
# [DEBUG submit()] vine_task_id=411, task.id=411
# [DEBUG submit()] vine_task_id=412, task.id=412
# [DEBUG submit()] vine_task_id=413, task.id=413
# [DEBUG submit()] vine_task_id=414, task.id=414
# [DEBUG submit()] vine_task_id=415, task.id=415
# [DEBUG submit()] vine_task_id=416, task.id=416
# [DEBUG submit()] vine_task_id=417, task.id=417
# [DEBUG submit()] vine_task_id=418, task.id=418
# [DEBUG submit()] vine_task_id=419, task.id=419
# [DEBUG submit()] vine_task_id=420, task.id=420
# [DEBUG submit()] vine_task_id=421, task.id=421
# [DEBUG submit()] vine_task_id=422, task.id=422
# [DEBUG submit()] vine_task_id=423, task.id=423
# [DEBUG submit()] vine_task_id=424, task.id=424
# [DEBUG submit()] vine_task_id=425, task.id=425
# [DEBUG submit()] vine_task_id=426, task.id=426
# [DEBUG submit()] vine_task_id=427, task.id=427
# [DEBUG submit()] vine_task_id=428, task.id=428
# [DEBUG submit()] vine_task_id=429, task.id=429
# [DEBUG submit()] vine_task_id=430, task.id=430
# [DEBUG submit()] vine_task_id=431, task.id=431
# [DEBUG submit()] vine_task_id=432, task.id=432
# [DEBUG submit()] vine_task_id=433, task.id=433
# [DEBUG submit()] vine_task_id=434, task.id=434
# [DEBUG submit()] vine_task_id=435, task.id=435
# [DEBUG submit()] vine_task_id=436, task.id=436
# [DEBUG submit()] vine_task_id=437, task.id=437
# [DEBUG submit()] vine_task_id=438, task.id=438
# [DEBUG submit()] vine_task_id=439, task.id=439
# [DEBUG submit()] vine_task_id=440, task.id=440
# [DEBUG submit()] vine_task_id=441, task.id=441
# [DEBUG submit()] vine_task_id=442, task.id=442
# [DEBUG submit()] vine_task_id=443, task.id=443
# [DEBUG submit()] vine_task_id=444, task.id=444
# [DEBUG submit()] vine_task_id=445, task.id=445
# [DEBUG submit()] vine_task_id=446, task.id=446
# [DEBUG submit()] vine_task_id=447, task.id=447
# [DEBUG submit()] vine_task_id=448, task.id=448
# [DEBUG submit()] vine_task_id=449, task.id=449
# [DEBUG submit()] vine_task_id=450, task.id=450
# [DEBUG submit()] vine_task_id=451, task.id=451
# [DEBUG submit()] vine_task_id=452, task.id=452
# [DEBUG submit()] vine_task_id=453, task.id=453
# [DEBUG submit()] vine_task_id=454, task.id=454
# [DEBUG submit()] vine_task_id=455, task.id=455
# [DEBUG submit()] vine_task_id=456, task.id=456
# [DEBUG submit()] vine_task_id=457, task.id=457
# [DEBUG submit()] vine_task_id=458, task.id=458
# [DEBUG submit()] vine_task_id=459, task.id=459
# [DEBUG submit()] vine_task_id=460, task.id=460
# [DEBUG submit()] vine_task_id=461, task.id=461
# [DEBUG submit()] vine_task_id=462, task.id=462
# [DEBUG submit()] vine_task_id=463, task.id=463
# [DEBUG submit()] vine_task_id=464, task.id=464
# [DEBUG submit()] vine_task_id=465, task.id=465
# [DEBUG submit()] vine_task_id=466, task.id=466
# [DEBUG submit()] vine_task_id=467, task.id=467
# [DEBUG submit()] vine_task_id=468, task.id=468
# [DEBUG submit()] vine_task_id=469, task.id=469
# [DEBUG submit()] vine_task_id=470, task.id=470
# [DEBUG submit()] vine_task_id=471, task.id=471
# [DEBUG submit()] vine_task_id=472, task.id=472
# [DEBUG submit()] vine_task_id=473, task.id=473
# [DEBUG submit()] vine_task_id=474, task.id=474
# [DEBUG submit()] vine_task_id=475, task.id=475
# [DEBUG submit()] vine_task_id=476, task.id=476
# [DEBUG submit()] vine_task_id=477, task.id=477
# [DEBUG submit()] vine_task_id=478, task.id=478
# [DEBUG submit()] vine_task_id=479, task.id=479
# [DEBUG submit()] vine_task_id=480, task.id=480
# [DEBUG submit()] vine_task_id=481, task.id=481
# [DEBUG submit()] vine_task_id=482, task.id=482
# [DEBUG submit()] vine_task_id=483, task.id=483
# [DEBUG submit()] vine_task_id=484, task.id=484
# [DEBUG submit()] vine_task_id=485, task.id=485
# [DEBUG submit()] vine_task_id=486, task.id=486
# [DEBUG submit()] vine_task_id=487, task.id=487
# [DEBUG submit()] vine_task_id=488, task.id=488
# [DEBUG submit()] vine_task_id=489, task.id=489
# [DEBUG submit()] vine_task_id=490, task.id=490
# [DEBUG submit()] vine_task_id=491, task.id=491
# [DEBUG submit()] vine_task_id=492, task.id=492
# [DEBUG submit()] vine_task_id=493, task.id=493
# [DEBUG submit()] vine_task_id=494, task.id=494
# [DEBUG submit()] vine_task_id=495, task.id=495
# [DEBUG submit()] vine_task_id=496, task.id=496
# [DEBUG submit()] vine_task_id=497, task.id=497
# [DEBUG submit()] vine_task_id=498, task.id=498
# [DEBUG submit()] vine_task_id=499, task.id=499
# [DEBUG submit()] vine_task_id=500, task.id=500
# [DEBUG submit()] vine_task_id=501, task.id=501
# [DEBUG submit()] vine_task_id=502, task.id=502
# [DEBUG submit()] vine_task_id=503, task.id=503
# [DEBUG submit()] vine_task_id=504, task.id=504
# [DEBUG submit()] vine_task_id=505, task.id=505
# [DEBUG submit()] vine_task_id=506, task.id=506
# [DEBUG submit()] vine_task_id=507, task.id=507
# [DEBUG submit()] vine_task_id=508, task.id=508
# [DEBUG submit()] vine_task_id=509, task.id=509
# [DEBUG submit()] vine_task_id=510, task.id=510
# [DEBUG submit()] vine_task_id=511, task.id=511
# [DEBUG submit()] vine_task_id=512, task.id=512
# [DEBUG submit()] vine_task_id=513, task.id=513
# [DEBUG submit()] vine_task_id=514, task.id=514
# [DEBUG submit()] vine_task_id=515, task.id=515
# [DEBUG submit()] vine_task_id=516, task.id=516
# [DEBUG submit()] vine_task_id=517, task.id=517
# [DEBUG submit()] vine_task_id=518, task.id=518
# [DEBUG submit()] vine_task_id=519, task.id=519
# [DEBUG submit()] vine_task_id=520, task.id=520
# [DEBUG submit()] vine_task_id=521, task.id=521
# [DEBUG submit()] vine_task_id=522, task.id=522
# [DEBUG submit()] vine_task_id=523, task.id=523
# [DEBUG submit()] vine_task_id=524, task.id=524
# [DEBUG submit()] vine_task_id=525, task.id=525
# [DEBUG submit()] vine_task_id=526, task.id=526
# [DEBUG submit()] vine_task_id=527, task.id=527
# [DEBUG submit()] vine_task_id=528, task.id=528
# [DEBUG submit()] vine_task_id=529, task.id=529
# [DEBUG submit()] vine_task_id=530, task.id=530
# [DEBUG submit()] vine_task_id=531, task.id=531
# [DEBUG submit()] vine_task_id=532, task.id=532
# [DEBUG submit()] vine_task_id=533, task.id=533
# [DEBUG submit()] vine_task_id=534, task.id=534
# [DEBUG submit()] vine_task_id=535, task.id=535
# [DEBUG submit()] vine_task_id=536, task.id=536
# [DEBUG submit()] vine_task_id=537, task.id=537
# [DEBUG submit()] vine_task_id=538, task.id=538
# [DEBUG submit()] vine_task_id=539, task.id=539
# [DEBUG submit()] vine_task_id=540, task.id=540
# [DEBUG submit()] vine_task_id=541, task.id=541
# [DEBUG submit()] vine_task_id=542, task.id=542
# [DEBUG submit()] vine_task_id=543, task.id=543
# [DEBUG submit()] vine_task_id=544, task.id=544
# [DEBUG submit()] vine_task_id=545, task.id=545
# [DEBUG submit()] vine_task_id=546, task.id=546
# [DEBUG submit()] vine_task_id=547, task.id=547
# [DEBUG submit()] vine_task_id=548, task.id=548
# [DEBUG submit()] vine_task_id=549, task.id=549
# [DEBUG submit()] vine_task_id=550, task.id=550
# [DEBUG submit()] vine_task_id=551, task.id=551
# [DEBUG submit()] vine_task_id=552, task.id=552
# [DEBUG submit()] vine_task_id=553, task.id=553
# [DEBUG submit()] vine_task_id=554, task.id=554
# [DEBUG submit()] vine_task_id=555, task.id=555
# [DEBUG submit()] vine_task_id=556, task.id=556
# [DEBUG submit()] vine_task_id=557, task.id=557
# [DEBUG submit()] vine_task_id=558, task.id=558
# [DEBUG submit()] vine_task_id=559, task.id=559
# [DEBUG submit()] vine_task_id=560, task.id=560
# [DEBUG submit()] vine_task_id=561, task.id=561
# [DEBUG submit()] vine_task_id=562, task.id=562
# [DEBUG submit()] vine_task_id=563, task.id=563
# [DEBUG submit()] vine_task_id=564, task.id=564
# [DEBUG submit()] vine_task_id=565, task.id=565
# [DEBUG submit()] vine_task_id=566, task.id=566
# [DEBUG submit()] vine_task_id=567, task.id=567
# [DEBUG submit()] vine_task_id=568, task.id=568
# [DEBUG submit()] vine_task_id=569, task.id=569
# [DEBUG submit()] vine_task_id=570, task.id=570
# [DEBUG submit()] vine_task_id=571, task.id=571
# [DEBUG submit()] vine_task_id=572, task.id=572
# [DEBUG submit()] vine_task_id=573, task.id=573
# [DEBUG submit()] vine_task_id=574, task.id=574
# [DEBUG submit()] vine_task_id=575, task.id=575
# [DEBUG submit()] vine_task_id=576, task.id=576
# [DEBUG submit()] vine_task_id=577, task.id=577
# [DEBUG submit()] vine_task_id=578, task.id=578
# [DEBUG submit()] vine_task_id=579, task.id=579
# [DEBUG submit()] vine_task_id=580, task.id=580
# [DEBUG submit()] vine_task_id=581, task.id=581
# [DEBUG submit()] vine_task_id=582, task.id=582
# [DEBUG submit()] vine_task_id=583, task.id=583
# [DEBUG submit()] vine_task_id=584, task.id=584
# [DEBUG submit()] vine_task_id=585, task.id=585
# [DEBUG submit()] vine_task_id=586, task.id=586
# [DEBUG submit()] vine_task_id=587, task.id=587
# [DEBUG submit()] vine_task_id=588, task.id=588
# [DEBUG submit()] vine_task_id=589, task.id=589
# [DEBUG submit()] vine_task_id=590, task.id=590
# [DEBUG submit()] vine_task_id=591, task.id=591
# [DEBUG submit()] vine_task_id=592, task.id=592
# [DEBUG submit()] vine_task_id=593, task.id=593
# [DEBUG submit()] vine_task_id=594, task.id=594
# [DEBUG submit()] vine_task_id=595, task.id=595
# [DEBUG submit()] vine_task_id=596, task.id=596
# [DEBUG submit()] vine_task_id=597, task.id=597
# [DEBUG submit()] vine_task_id=598, task.id=598
# [DEBUG submit()] vine_task_id=599, task.id=599
# [DEBUG submit()] vine_task_id=600, task.id=600
# [DEBUG submit()] vine_task_id=601, task.id=601
# [DEBUG submit()] vine_task_id=602, task.id=602
# [DEBUG submit()] vine_task_id=603, task.id=603
# [DEBUG submit()] vine_task_id=604, task.id=604
# [DEBUG submit()] vine_task_id=605, task.id=605
# [DEBUG submit()] vine_task_id=606, task.id=606
# [DEBUG submit()] vine_task_id=607, task.id=607
# [DEBUG submit()] vine_task_id=608, task.id=608
# [DEBUG submit()] vine_task_id=609, task.id=609
# [DEBUG submit()] vine_task_id=610, task.id=610
# [DEBUG submit()] vine_task_id=611, task.id=611
# [DEBUG submit()] vine_task_id=612, task.id=612
# [DEBUG submit()] vine_task_id=613, task.id=613
# [DEBUG submit()] vine_task_id=614, task.id=614
# [DEBUG submit()] vine_task_id=615, task.id=615
# [DEBUG submit()] vine_task_id=616, task.id=616
# [DEBUG submit()] vine_task_id=617, task.id=617
# [DEBUG submit()] vine_task_id=618, task.id=618
# [DEBUG submit()] vine_task_id=619, task.id=619
# [DEBUG submit()] vine_task_id=620, task.id=620
# [DEBUG submit()] vine_task_id=621, task.id=621
# [DEBUG submit()] vine_task_id=622, task.id=622
# [DEBUG submit()] vine_task_id=623, task.id=623
# [DEBUG submit()] vine_task_id=624, task.id=624
# [DEBUG submit()] vine_task_id=625, task.id=625
# [DEBUG submit()] vine_task_id=626, task.id=626
# [DEBUG submit()] vine_task_id=627, task.id=627
# [DEBUG submit()] vine_task_id=628, task.id=628
# [DEBUG submit()] vine_task_id=629, task.id=629
# [DEBUG submit()] vine_task_id=630, task.id=630
# [DEBUG submit()] vine_task_id=631, task.id=631
# [DEBUG submit()] vine_task_id=632, task.id=632
# [DEBUG submit()] vine_task_id=633, task.id=633
# [DEBUG submit()] vine_task_id=634, task.id=634
# [DEBUG submit()] vine_task_id=635, task.id=635
# [DEBUG submit()] vine_task_id=636, task.id=636
# [DEBUG submit()] vine_task_id=637, task.id=637
# [DEBUG submit()] vine_task_id=638, task.id=638
# [DEBUG submit()] vine_task_id=639, task.id=639
# [DEBUG submit()] vine_task_id=640, task.id=640
# [DEBUG submit()] vine_task_id=641, task.id=641
# [DEBUG submit()] vine_task_id=642, task.id=642
# [DEBUG submit()] vine_task_id=643, task.id=643
# [DEBUG submit()] vine_task_id=644, task.id=644
# [DEBUG submit()] vine_task_id=645, task.id=645
# [DEBUG submit()] vine_task_id=646, task.id=646
# [DEBUG submit()] vine_task_id=647, task.id=647
# [DEBUG submit()] vine_task_id=648, task.id=648
# [DEBUG submit()] vine_task_id=649, task.id=649
# [DEBUG submit()] vine_task_id=650, task.id=650
# [DEBUG submit()] vine_task_id=651, task.id=651
# [DEBUG submit()] vine_task_id=652, task.id=652
# [DEBUG submit()] vine_task_id=653, task.id=653
# [DEBUG submit()] vine_task_id=654, task.id=654
# [DEBUG submit()] vine_task_id=655, task.id=655
# [DEBUG submit()] vine_task_id=656, task.id=656
# [DEBUG submit()] vine_task_id=657, task.id=657
# [DEBUG submit()] vine_task_id=658, task.id=658
# [DEBUG submit()] vine_task_id=659, task.id=659
# [DEBUG submit()] vine_task_id=660, task.id=660
# [DEBUG submit()] vine_task_id=661, task.id=661
# [DEBUG submit()] vine_task_id=662, task.id=662
# [DEBUG submit()] vine_task_id=663, task.id=663
# [DEBUG submit()] vine_task_id=664, task.id=664
# [DEBUG submit()] vine_task_id=665, task.id=665
# [DEBUG submit()] vine_task_id=666, task.id=666
# [DEBUG submit()] vine_task_id=667, task.id=667
# [DEBUG submit()] vine_task_id=668, task.id=668
# [DEBUG submit()] vine_task_id=669, task.id=669
# [DEBUG submit()] vine_task_id=670, task.id=670
# [DEBUG submit()] vine_task_id=671, task.id=671
# [DEBUG submit()] vine_task_id=672, task.id=672
# [DEBUG submit()] vine_task_id=673, task.id=673
# [DEBUG submit()] vine_task_id=674, task.id=674
# [DEBUG submit()] vine_task_id=675, task.id=675
# [DEBUG submit()] vine_task_id=676, task.id=676
# [DEBUG submit()] vine_task_id=677, task.id=677
# [DEBUG submit()] vine_task_id=678, task.id=678
# [DEBUG submit()] vine_task_id=679, task.id=679
# [DEBUG submit()] vine_task_id=680, task.id=680
# [DEBUG submit()] vine_task_id=681, task.id=681
# [DEBUG submit()] vine_task_id=682, task.id=682
# [DEBUG submit()] vine_task_id=683, task.id=683
# [DEBUG submit()] vine_task_id=684, task.id=684
# [DEBUG submit()] vine_task_id=685, task.id=685
# [DEBUG submit()] vine_task_id=686, task.id=686
# [DEBUG submit()] vine_task_id=687, task.id=687
# [DEBUG submit()] vine_task_id=688, task.id=688
# [DEBUG submit()] vine_task_id=689, task.id=689
# [DEBUG submit()] vine_task_id=690, task.id=690
# [DEBUG submit()] vine_task_id=691, task.id=691
# [DEBUG submit()] vine_task_id=692, task.id=692
# [DEBUG submit()] vine_task_id=693, task.id=693
# [DEBUG submit()] vine_task_id=694, task.id=694
# [DEBUG submit()] vine_task_id=695, task.id=695
# [DEBUG submit()] vine_task_id=696, task.id=696
# [DEBUG submit()] vine_task_id=697, task.id=697
# [DEBUG submit()] vine_task_id=698, task.id=698
# [DEBUG submit()] vine_task_id=699, task.id=699
# [DEBUG submit()] vine_task_id=700, task.id=700
# [DEBUG submit()] vine_task_id=701, task.id=701
# [DEBUG submit()] vine_task_id=702, task.id=702
# [DEBUG submit()] vine_task_id=703, task.id=703
# [DEBUG submit()] vine_task_id=704, task.id=704
# [DEBUG submit()] vine_task_id=705, task.id=705
# [DEBUG submit()] vine_task_id=706, task.id=706
# [DEBUG submit()] vine_task_id=707, task.id=707
# [DEBUG submit()] vine_task_id=708, task.id=708
# [DEBUG submit()] vine_task_id=709, task.id=709
# [DEBUG submit()] vine_task_id=710, task.id=710
# [DEBUG submit()] vine_task_id=711, task.id=711
# [DEBUG submit()] vine_task_id=712, task.id=712
# [DEBUG submit()] vine_task_id=713, task.id=713
# [DEBUG submit()] vine_task_id=714, task.id=714
# [DEBUG submit()] vine_task_id=715, task.id=715
# [DEBUG submit()] vine_task_id=716, task.id=716
# [DEBUG submit()] vine_task_id=717, task.id=717
# [DEBUG submit()] vine_task_id=718, task.id=718
# [DEBUG submit()] vine_task_id=719, task.id=719
# [DEBUG submit()] vine_task_id=720, task.id=720
# [DEBUG submit()] vine_task_id=721, task.id=721
# [DEBUG submit()] vine_task_id=722, task.id=722
# [DEBUG submit()] vine_task_id=723, task.id=723
# [DEBUG submit()] vine_task_id=724, task.id=724
# [DEBUG submit()] vine_task_id=725, task.id=725
# [DEBUG submit()] vine_task_id=726, task.id=726
# [DEBUG submit()] vine_task_id=727, task.id=727
# [DEBUG submit()] vine_task_id=728, task.id=728
# [DEBUG submit()] vine_task_id=729, task.id=729
# [DEBUG submit()] vine_task_id=730, task.id=730
# [DEBUG submit()] vine_task_id=731, task.id=731
# [DEBUG submit()] vine_task_id=732, task.id=732
# [DEBUG submit()] vine_task_id=733, task.id=733
# [DEBUG submit()] vine_task_id=734, task.id=734
# [DEBUG submit()] vine_task_id=735, task.id=735
# [DEBUG submit()] vine_task_id=736, task.id=736
# [DEBUG submit()] vine_task_id=737, task.id=737
# [DEBUG submit()] vine_task_id=738, task.id=738
# [DEBUG submit()] vine_task_id=739, task.id=739
# [DEBUG submit()] vine_task_id=740, task.id=740
# [DEBUG submit()] vine_task_id=741, task.id=741
# [DEBUG submit()] vine_task_id=742, task.id=742
# [DEBUG submit()] vine_task_id=743, task.id=743
# [DEBUG submit()] vine_task_id=744, task.id=744
# [DEBUG submit()] vine_task_id=745, task.id=745
# [DEBUG submit()] vine_task_id=746, task.id=746
# [DEBUG submit()] vine_task_id=747, task.id=747
# [DEBUG submit()] vine_task_id=748, task.id=748
# [DEBUG submit()] vine_task_id=749, task.id=749
# [DEBUG submit()] vine_task_id=750, task.id=750
# [DEBUG submit()] vine_task_id=751, task.id=751
# [DEBUG submit()] vine_task_id=752, task.id=752
# [DEBUG submit()] vine_task_id=753, task.id=753
# [DEBUG submit()] vine_task_id=754, task.id=754
# [DEBUG submit()] vine_task_id=755, task.id=755
# [DEBUG submit()] vine_task_id=756, task.id=756
# [DEBUG submit()] vine_task_id=757, task.id=757
# [DEBUG submit()] vine_task_id=758, task.id=758
# [DEBUG submit()] vine_task_id=759, task.id=759
# [DEBUG submit()] vine_task_id=760, task.id=760
# [DEBUG submit()] vine_task_id=761, task.id=761
# [DEBUG submit()] vine_task_id=762, task.id=762
# [DEBUG submit()] vine_task_id=763, task.id=763
# [DEBUG submit()] vine_task_id=764, task.id=764
# [DEBUG submit()] vine_task_id=765, task.id=765
# [DEBUG submit()] vine_task_id=766, task.id=766
# [DEBUG submit()] vine_task_id=767, task.id=767
# [DEBUG submit()] vine_task_id=768, task.id=768
# [DEBUG submit()] vine_task_id=769, task.id=769
# [DEBUG submit()] vine_task_id=770, task.id=770
# [DEBUG submit()] vine_task_id=771, task.id=771
# [DEBUG submit()] vine_task_id=772, task.id=772
# [DEBUG submit()] vine_task_id=773, task.id=773
# [DEBUG submit()] vine_task_id=774, task.id=774
# [DEBUG submit()] vine_task_id=775, task.id=775
# [DEBUG submit()] vine_task_id=776, task.id=776
# [DEBUG submit()] vine_task_id=777, task.id=777
# [DEBUG submit()] vine_task_id=778, task.id=778
# [DEBUG submit()] vine_task_id=779, task.id=779
# [DEBUG submit()] vine_task_id=780, task.id=780
# [DEBUG submit()] vine_task_id=781, task.id=781
# [DEBUG submit()] vine_task_id=782, task.id=782
# [DEBUG submit()] vine_task_id=783, task.id=783
# [DEBUG submit()] vine_task_id=784, task.id=784
# [DEBUG submit()] vine_task_id=785, task.id=785
# [DEBUG submit()] vine_task_id=786, task.id=786
# [DEBUG submit()] vine_task_id=787, task.id=787
# [DEBUG submit()] vine_task_id=788, task.id=788
# [DEBUG submit()] vine_task_id=789, task.id=789
# [DEBUG submit()] vine_task_id=790, task.id=790
# [DEBUG submit()] vine_task_id=791, task.id=791
# [DEBUG submit()] vine_task_id=792, task.id=792
# [DEBUG submit()] vine_task_id=793, task.id=793
# [DEBUG submit()] vine_task_id=794, task.id=794
# [DEBUG submit()] vine_task_id=795, task.id=795
# [DEBUG submit()] vine_task_id=796, task.id=796
# [DEBUG submit()] vine_task_id=797, task.id=797
# [DEBUG submit()] vine_task_id=798, task.id=798
# [DEBUG submit()] vine_task_id=799, task.id=799
# [DEBUG submit()] vine_task_id=800, task.id=800
# [DEBUG submit()] vine_task_id=801, task.id=801
# [DEBUG submit()] vine_task_id=802, task.id=802
# [DEBUG submit()] vine_task_id=803, task.id=803
# [DEBUG submit()] vine_task_id=804, task.id=804
# [DEBUG submit()] vine_task_id=805, task.id=805
# [DEBUG submit()] vine_task_id=806, task.id=806
# [DEBUG submit()] vine_task_id=807, task.id=807
# [DEBUG submit()] vine_task_id=808, task.id=808
# [DEBUG submit()] vine_task_id=809, task.id=809
# [DEBUG submit()] vine_task_id=810, task.id=810
# [DEBUG submit()] vine_task_id=811, task.id=811
# [DEBUG submit()] vine_task_id=812, task.id=812
# [DEBUG submit()] vine_task_id=813, task.id=813
# [DEBUG submit()] vine_task_id=814, task.id=814
# [DEBUG submit()] vine_task_id=815, task.id=815
# [DEBUG submit()] vine_task_id=816, task.id=816
# [DEBUG submit()] vine_task_id=817, task.id=817
# [DEBUG submit()] vine_task_id=818, task.id=818
# [DEBUG submit()] vine_task_id=819, task.id=819
# [DEBUG submit()] vine_task_id=820, task.id=820
# [DEBUG submit()] vine_task_id=821, task.id=821
# [DEBUG submit()] vine_task_id=822, task.id=822
# [DEBUG submit()] vine_task_id=823, task.id=823
# [DEBUG submit()] vine_task_id=824, task.id=824
# [DEBUG submit()] vine_task_id=825, task.id=825
# [DEBUG submit()] vine_task_id=826, task.id=826
# [DEBUG submit()] vine_task_id=827, task.id=827
# [DEBUG submit()] vine_task_id=828, task.id=828
# [DEBUG submit()] vine_task_id=829, task.id=829
# [DEBUG submit()] vine_task_id=830, task.id=830
# [DEBUG submit()] vine_task_id=831, task.id=831
# [DEBUG submit()] vine_task_id=832, task.id=832
# [DEBUG submit()] vine_task_id=833, task.id=833
# [DEBUG submit()] vine_task_id=834, task.id=834
# [DEBUG submit()] vine_task_id=835, task.id=835
# [DEBUG submit()] vine_task_id=836, task.id=836
# [DEBUG submit()] vine_task_id=837, task.id=837
# [DEBUG submit()] vine_task_id=838, task.id=838
# [DEBUG submit()] vine_task_id=839, task.id=839
# [DEBUG submit()] vine_task_id=840, task.id=840
# [DEBUG submit()] vine_task_id=841, task.id=841
# [DEBUG submit()] vine_task_id=842, task.id=842
# [DEBUG submit()] vine_task_id=843, task.id=843
# [DEBUG submit()] vine_task_id=844, task.id=844
# [DEBUG submit()] vine_task_id=845, task.id=845
# [DEBUG submit()] vine_task_id=846, task.id=846
# [DEBUG submit()] vine_task_id=847, task.id=847
# [DEBUG submit()] vine_task_id=848, task.id=848
# [DEBUG submit()] vine_task_id=849, task.id=849
# [DEBUG submit()] vine_task_id=850, task.id=850
# [DEBUG submit()] vine_task_id=851, task.id=851
# [DEBUG submit()] vine_task_id=852, task.id=852
# [DEBUG submit()] vine_task_id=853, task.id=853
# [DEBUG submit()] vine_task_id=854, task.id=854
# [DEBUG submit()] vine_task_id=855, task.id=855
# [DEBUG submit()] vine_task_id=856, task.id=856
# [DEBUG submit()] vine_task_id=857, task.id=857
# [DEBUG submit()] vine_task_id=858, task.id=858
# [DEBUG submit()] vine_task_id=859, task.id=859
# [DEBUG submit()] vine_task_id=860, task.id=860
# [DEBUG submit()] vine_task_id=861, task.id=861
# [DEBUG submit()] vine_task_id=862, task.id=862
# [DEBUG submit()] vine_task_id=863, task.id=863
# [DEBUG submit()] vine_task_id=864, task.id=864
# [DEBUG submit()] vine_task_id=865, task.id=865
# [DEBUG submit()] vine_task_id=866, task.id=866
# [DEBUG submit()] vine_task_id=867, task.id=867
# [DEBUG submit()] vine_task_id=868, task.id=868
# [DEBUG submit()] vine_task_id=869, task.id=869
# [DEBUG submit()] vine_task_id=870, task.id=870
# [DEBUG submit()] vine_task_id=871, task.id=871
# [DEBUG submit()] vine_task_id=872, task.id=872
# [DEBUG submit()] vine_task_id=873, task.id=873
# [DEBUG submit()] vine_task_id=874, task.id=874
# [DEBUG submit()] vine_task_id=875, task.id=875
# [DEBUG submit()] vine_task_id=876, task.id=876
# [DEBUG submit()] vine_task_id=877, task.id=877
# [DEBUG submit()] vine_task_id=878, task.id=878
# [DEBUG submit()] vine_task_id=879, task.id=879
# [DEBUG submit()] vine_task_id=880, task.id=880
# [DEBUG submit()] vine_task_id=881, task.id=881
# [DEBUG submit()] vine_task_id=882, task.id=882
# [DEBUG submit()] vine_task_id=883, task.id=883
# [DEBUG submit()] vine_task_id=884, task.id=884
# [DEBUG submit()] vine_task_id=885, task.id=885
# [DEBUG submit()] vine_task_id=886, task.id=886
# [DEBUG submit()] vine_task_id=887, task.id=887
# [DEBUG submit()] vine_task_id=888, task.id=888
# [DEBUG submit()] vine_task_id=889, task.id=889
# [DEBUG submit()] vine_task_id=890, task.id=890
# [DEBUG submit()] vine_task_id=891, task.id=891
# [DEBUG submit()] vine_task_id=892, task.id=892
# [DEBUG submit()] vine_task_id=893, task.id=893
# [DEBUG submit()] vine_task_id=894, task.id=894
# [DEBUG submit()] vine_task_id=895, task.id=895
# [DEBUG submit()] vine_task_id=896, task.id=896
# [DEBUG submit()] vine_task_id=897, task.id=897
# [DEBUG submit()] vine_task_id=898, task.id=898
# [DEBUG submit()] vine_task_id=899, task.id=899
# [DEBUG submit()] vine_task_id=900, task.id=900
# [DEBUG submit()] vine_task_id=901, task.id=901
# [DEBUG submit()] vine_task_id=902, task.id=902
# [DEBUG submit()] vine_task_id=903, task.id=903
# [DEBUG submit()] vine_task_id=904, task.id=904
# [DEBUG submit()] vine_task_id=905, task.id=905
# [DEBUG submit()] vine_task_id=906, task.id=906
# [DEBUG submit()] vine_task_id=907, task.id=907
# [DEBUG submit()] vine_task_id=908, task.id=908
# [DEBUG submit()] vine_task_id=909, task.id=909
# [DEBUG submit()] vine_task_id=910, task.id=910
# [DEBUG submit()] vine_task_id=911, task.id=911
# [DEBUG submit()] vine_task_id=912, task.id=912
# [DEBUG submit()] vine_task_id=913, task.id=913
# [DEBUG submit()] vine_task_id=914, task.id=914
# [DEBUG submit()] vine_task_id=915, task.id=915
# [DEBUG submit()] vine_task_id=916, task.id=916
# [DEBUG submit()] vine_task_id=917, task.id=917
# [DEBUG submit()] vine_task_id=918, task.id=918
# [DEBUG submit()] vine_task_id=919, task.id=919
# [DEBUG submit()] vine_task_id=920, task.id=920
# [DEBUG submit()] vine_task_id=921, task.id=921
# [DEBUG submit()] vine_task_id=922, task.id=922
# [DEBUG submit()] vine_task_id=923, task.id=923
# [DEBUG submit()] vine_task_id=924, task.id=924
# [DEBUG submit()] vine_task_id=925, task.id=925
# [DEBUG submit()] vine_task_id=926, task.id=926
# [DEBUG submit()] vine_task_id=927, task.id=927
# [DEBUG submit()] vine_task_id=928, task.id=928
# [DEBUG submit()] vine_task_id=929, task.id=929
# [DEBUG submit()] vine_task_id=930, task.id=930
# [DEBUG submit()] vine_task_id=931, task.id=931
# [DEBUG submit()] vine_task_id=932, task.id=932
# [DEBUG submit()] vine_task_id=933, task.id=933
# [DEBUG submit()] vine_task_id=934, task.id=934
# [DEBUG submit()] vine_task_id=935, task.id=935
# [DEBUG submit()] vine_task_id=936, task.id=936
# [DEBUG submit()] vine_task_id=937, task.id=937
# [DEBUG submit()] vine_task_id=938, task.id=938
# [DEBUG submit()] vine_task_id=939, task.id=939
# [DEBUG submit()] vine_task_id=940, task.id=940
# [DEBUG submit()] vine_task_id=941, task.id=941
# [DEBUG submit()] vine_task_id=942, task.id=942
# [DEBUG submit()] vine_task_id=943, task.id=943
# [DEBUG submit()] vine_task_id=944, task.id=944
# [DEBUG submit()] vine_task_id=945, task.id=945
# [DEBUG submit()] vine_task_id=946, task.id=946
# [DEBUG submit()] vine_task_id=947, task.id=947
# [DEBUG submit()] vine_task_id=948, task.id=948
# [DEBUG submit()] vine_task_id=949, task.id=949
# [DEBUG submit()] vine_task_id=950, task.id=950
# [DEBUG submit()] vine_task_id=951, task.id=951
# [DEBUG submit()] vine_task_id=952, task.id=952
# [DEBUG submit()] vine_task_id=953, task.id=953
# [DEBUG submit()] vine_task_id=954, task.id=954
# [DEBUG submit()] vine_task_id=955, task.id=955
# [DEBUG submit()] vine_task_id=956, task.id=956
# [DEBUG submit()] vine_task_id=957, task.id=957
# [DEBUG submit()] vine_task_id=958, task.id=958
# [DEBUG submit()] vine_task_id=959, task.id=959
# [DEBUG submit()] vine_task_id=960, task.id=960
# [DEBUG submit()] vine_task_id=961, task.id=961
# [DEBUG submit()] vine_task_id=962, task.id=962
# [DEBUG submit()] vine_task_id=963, task.id=963
# [DEBUG submit()] vine_task_id=964, task.id=964
# [DEBUG submit()] vine_task_id=965, task.id=965
# [DEBUG submit()] vine_task_id=966, task.id=966
# [DEBUG submit()] vine_task_id=967, task.id=967
# [DEBUG submit()] vine_task_id=968, task.id=968
# [DEBUG submit()] vine_task_id=969, task.id=969
# [DEBUG submit()] vine_task_id=970, task.id=970
# [DEBUG submit()] vine_task_id=971, task.id=971
# [DEBUG submit()] vine_task_id=972, task.id=972
# [DEBUG submit()] vine_task_id=973, task.id=973
# [DEBUG submit()] vine_task_id=974, task.id=974
# [DEBUG submit()] vine_task_id=975, task.id=975
# [DEBUG submit()] vine_task_id=976, task.id=976
# [DEBUG submit()] vine_task_id=977, task.id=977
# [DEBUG submit()] vine_task_id=978, task.id=978
# [DEBUG submit()] vine_task_id=979, task.id=979
# [DEBUG submit()] vine_task_id=980, task.id=980
# [DEBUG submit()] vine_task_id=981, task.id=981
# [DEBUG submit()] vine_task_id=982, task.id=982
# [DEBUG submit()] vine_task_id=983, task.id=983
# [DEBUG submit()] vine_task_id=984, task.id=984
# [DEBUG submit()] vine_task_id=985, task.id=985
# [DEBUG submit()] vine_task_id=986, task.id=986
# [DEBUG submit()] vine_task_id=987, task.id=987
# [DEBUG submit()] vine_task_id=988, task.id=988
# [DEBUG submit()] vine_task_id=989, task.id=989
# [DEBUG submit()] vine_task_id=990, task.id=990
# [DEBUG submit()] vine_task_id=991, task.id=991
# [DEBUG submit()] vine_task_id=992, task.id=992
# [DEBUG submit()] vine_task_id=993, task.id=993
# [DEBUG submit()] vine_task_id=994, task.id=994
# [DEBUG submit()] vine_task_id=995, task.id=995
# [DEBUG submit()] vine_task_id=996, task.id=996
# [DEBUG submit()] vine_task_id=997, task.id=997
# [DEBUG submit()] vine_task_id=998, task.id=998
# [DEBUG submit()] vine_task_id=999, task.id=999
# [DEBUG submit()] vine_task_id=1000, task.id=1000
# [DEBUG submit()] vine_task_id=1001, task.id=1001
# [DEBUG submit()] vine_task_id=1002, task.id=1002
# [DEBUG submit()] vine_task_id=1003, task.id=1003
# [DEBUG submit()] vine_task_id=1004, task.id=1004
# [DEBUG submit()] vine_task_id=1005, task.id=1005
# [DEBUG submit()] vine_task_id=1006, task.id=1006
# [DEBUG submit()] vine_task_id=1007, task.id=1007
# [DEBUG submit()] vine_task_id=1008, task.id=1008
# [DEBUG submit()] vine_task_id=1009, task.id=1009
# [DEBUG submit()] vine_task_id=1010, task.id=1010
# [DEBUG submit()] vine_task_id=1011, task.id=1011
# [DEBUG submit()] vine_task_id=1012, task.id=1012
# [DEBUG submit()] vine_task_id=1013, task.id=1013
# [DEBUG submit()] vine_task_id=1014, task.id=1014
# [DEBUG submit()] vine_task_id=1015, task.id=1015
# [DEBUG submit()] vine_task_id=1016, task.id=1016
# [DEBUG submit()] vine_task_id=1017, task.id=1017
# [DEBUG submit()] vine_task_id=1018, task.id=1018
# [DEBUG submit()] vine_task_id=1019, task.id=1019
# [DEBUG submit()] vine_task_id=1020, task.id=1020
# [DEBUG submit()] vine_task_id=1021, task.id=1021
# ...
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/01d548cc16a816c07cf6628fd2e49a1ae85df4a99123a28a18ce5588221052c0.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# 900
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/e97ddd79e19f172d63f63d60a56a8b3b874042da95cad409fe077a5c50e6c5d3.output
# [DEBUG] Copied PythonTask output to: vine_outputs/82e43e0f0a3c72cf07bd4a67af2b509a826be0c47f3407b16b08b9158039001b.output
# [DEBUG] Copied PythonTask output to: vine_outputs/c453da4e358ebfead2418c5fae1b58c8a74e7d122565e2f8f9a6a4292f68a912.output
# [DEBUG] Copied PythonTask output to: vine_outputs/734e7093de1f97527243c3f6a0ade9b5e7bcb49e0159fb6cb7a0e0b2b40182b6.output
# [DEBUG] Copied PythonTask output to: vine_outputs/29a55629f883e90c64c694421b136a80cbf3c6fe045d449a848ebae385fe588b.output
# [DEBUG] Copied PythonTask output to: vine_outputs/13157ef74d0a58c030a575e569d989427d2eb561559bf3a80c27ec0a137f1090.output
# [DEBUG] Copied PythonTask output to: vine_outputs/10bd475eedccd96b29c4bb467f6371ce5bbf34f732febab8e46dcd9eeeb2aa4e.output
# [DEBUG] Copied PythonTask output to: vine_outputs/36e0271301cb505fa82385016db93c579a506a361b70630e6f85b88e3bb9e0d2.output
# [DEBUG] Copied PythonTask output to: vine_outputs/4d75720abade8c4bd7568d8ef20da00803c81b07defe592abe900779e66fb1c8.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/01d548cc16a816c07cf6628fd2e49a1ae85df4a99123a28a18ce5588221052c0.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# 950
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/01d548cc16a816c07cf6628fd2e49a1ae85df4a99123a28a18ce5588221052c0.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/499090dca860ca0813e1471acf363465b8c388bb85be2943f8beb0aaf500c8db.output
# [DEBUG] Copied PythonTask output to: vine_outputs/01d548cc16a816c07cf6628fd2e49a1ae85df4a99123a28a18ce5588221052c0.output
# [DEBUG] Copied PythonTask output to: vine_outputs/c041d60532a95972d84ad1ae095cd31d5e7a6030711fe4103f30f11701843c52.output
# [DEBUG] Copied PythonTask output to: vine_outputs/c041d60532a95972d84ad1ae095cd31d5e7a6030711fe4103f30f11701843c52.output
# [DEBUG] Copied PythonTask output to: vine_outputs/c041d60532a95972d84ad1ae095cd31d5e7a6030711fe4103f30f11701843c52.output
# [DEBUG] Copied PythonTask output to: vine_outputs/c041d60532a95972d84ad1ae095cd31d5e7a6030711fe4103f30f11701843c52.output
# [DEBUG] Copied PythonTask output to: vine_outputs/c041d60532a95972d84ad1ae095cd31d5e7a6030711fe4103f30f11701843c52.output
# [DEBUG] Copied PythonTask output to: vine_outputs/c041d60532a95972d84ad1ae095cd31d5e7a6030711fe4103f30f11701843c52.output
# [DEBUG] Copied PythonTask output to: vine_outputs/c041d60532a95972d84ad1ae095cd31d5e7a6030711fe4103f30f11701843c52.output
# [DEBUG] Copied PythonTask output to: vine_outputs/c041d60532a95972d84ad1ae095cd31d5e7a6030711fe4103f30f11701843c52.output
# 1000
# [DEBUG] Copied PythonTask output to: vine_outputs/c041d60532a95972d84ad1ae095cd31d5e7a6030711fe4103f30f11701843c52.output
# [DEBUG] Copied PythonTask output to: vine_outputs/c041d60532a95972d84ad1ae095cd31d5e7a6030711fe4103f30f11701843c52.output
# [DEBUG] Copied PythonTask output to: vine_outputs/c041d60532a95972d84ad1ae095cd31d5e7a6030711fe4103f30f11701843c52.output
# [DEBUG] Copied PythonTask output to: vine_outputs/c041d60532a95972d84ad1ae095cd31d5e7a6030711fe4103f30f11701843c52.output
# [DEBUG] Copied PythonTask output to: vine_outputs/c041d60532a95972d84ad1ae095cd31d5e7a6030711fe4103f30f11701843c52.output
# [DEBUG] Copied PythonTask output to: vine_outputs/c041d60532a95972d84ad1ae095cd31d5e7a6030711fe4103f30f11701843c52.output
# [DEBUG] Copied PythonTask output to: vine_outputs/c041d60532a95972d84ad1ae095cd31d5e7a6030711fe4103f30f11701843c52.output
# [DEBUG] Copied PythonTask output to: vine_outputs/c041d60532a95972d84ad1ae095cd31d5e7a6030711fe4103f30f11701843c52.output
# [DEBUG] Copied PythonTask output to: vine_outputs/c041d60532a95972d84ad1ae095cd31d5e7a6030711fe4103f30f11701843c52.output
# [DEBUG] Copied PythonTask output to: vine_outputs/c041d60532a95972d84ad1ae095cd31d5e7a6030711fe4103f30f11701843c52.output
# [DEBUG] Copied PythonTask output to: vine_outputs/c041d60532a95972d84ad1ae095cd31d5e7a6030711fe4103f30f11701843c52.output
# [DEBUG] Copied PythonTask output to: vine_outputs/c041d60532a95972d84ad1ae095cd31d5e7a6030711fe4103f30f11701843c52.output
# [DEBUG] Copied PythonTask output to: vine_outputs/c041d60532a95972d84ad1ae095cd31d5e7a6030711fe4103f30f11701843c52.output
# [DEBUG] Copied PythonTask output to: vine_outputs/c041d60532a95972d84ad1ae095cd31d5e7a6030711fe4103f30f11701843c52.output
# [DEBUG] Copied PythonTask output to: vine_outputs/c041d60532a95972d84ad1ae095cd31d5e7a6030711fe4103f30f11701843c52.output
# [DEBUG] Copied PythonTask output to: vine_outputs/c041d60532a95972d84ad1ae095cd31d5e7a6030711fe4103f30f11701843c52.output
# [DEBUG] Copied PythonTask output to: vine_outputs/c041d60532a95972d84ad1ae095cd31d5e7a6030711fe4103f30f11701843c52.output
# [DEBUG] Copied PythonTask output to: vine_outputs/c041d60532a95972d84ad1ae095cd31d5e7a6030711fe4103f30f11701843c52.output
# [DEBUG] Copied PythonTask output to: vine_outputs/c041d60532a95972d84ad1ae095cd31d5e7a6030711fe4103f30f11701843c52.output
# [DEBUG] Copied PythonTask output to: vine_outputs/c041d60532a95972d84ad1ae095cd31d5e7a6030711fe4103f30f11701843c52.output
# [DEBUG] Copied PythonTask output to: vine_outputs/c041d60532a95972d84ad1ae095cd31d5e7a6030711fe4103f30f11701843c52.output
# [DEBUG] Copied PythonTask output to: vine_outputs/c041d60532a95972d84ad1ae095cd31d5e7a6030711fe4103f30f11701843c52.output
# [DEBUG] Copied PythonTask output to: vine_outputs/c041d60532a95972d84ad1ae095cd31d5e7a6030711fe4103f30f11701843c52.output
# [DEBUG] Copied PythonTask output to: vine_outputs/16a5fe263dbfb70c6f25892cf0d88bc32d8018579a487cc810ab71e8139bd80d.output
# [output] saved 'npp_sharpen.jpg.jpg'
# CPU times: user 8.67 s, sys: 4 s, total: 12.7 s
# Wall time: 3min 11s

# %% [markdown]
# ## Results: quick side-by-side preview
#
# We down-sample each image ( ≤ 1024 px on the long edge ) and display them
# next to each other.  The full-resolution filtered file lives on disk.

# %%
# keep for preview
ORIGINAL_IMG  = img_gray
FILTERED_IMG  = filtered_img

# %%
import matplotlib.pyplot as plt
from PIL import Image

def show_preview(pil_img: Image.Image, max_dim: int = 1024) -> Image.Image:
    """Return a down-sampled copy (≤ max_dim on the long edge)."""
    preview = pil_img.copy()
    preview.thumbnail((max_dim, max_dim))
    return preview

orig_preview  = show_preview(ORIGINAL_IMG)
filt_preview  = show_preview(FILTERED_IMG)

fig, ax = plt.subplots(1, 2, figsize=(20, 10))
ax[0].imshow(orig_preview, cmap="gray")
ax[0].set_title("Original")
ax[0].axis("off")

ax[1].imshow(filt_preview, cmap="gray")
ax[1].set_title(f"Filtered ({SELECT_KERNEL})")
ax[1].axis("off")

plt.tight_layout()
plt.show()
